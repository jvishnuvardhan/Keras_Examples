# %% [markdown]
# <a href="https://colab.research.google.com/github/jvishnuvardhan/Keras_Examples/blob/master/model_history.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow==2.0.0rc1
# Out:
# ...
#      |████████████████████████████████| 86.3MB 51.9MB/s
# ...
#      |████████████████████████████████| 501kB 56.7MB/s
# ...
#      |████████████████████████████████| 4.3MB 52.2MB/s
# ...
#   Found existing installation: tf-estimator-nightly 1.14.0.dev2019090401
#     Uninstalling tf-estimator-nightly-1.14.0.dev2019090401:
#       Successfully uninstalled tf-estimator-nightly-1.14.0.dev2019090401
#   Found existing installation: tb-nightly 1.15.0a20190821
#     Uninstalling tb-nightly-1.15.0a20190821:
#       Successfully uninstalled tb-nightly-1.15.0a20190821
#   Found existing installation: tensorflow 1.15.0rc0
#     Uninstalling tensorflow-1.15.0rc0:
#       Successfully uninstalled tensorflow-1.15.0rc0
# ...

# %%
import tensorflow as tf
mnist = tf.keras.datasets.mnist

(x_train, y_train),(x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(512, activation=tf.nn.relu),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# ...
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
model_history=model.fit(x_train, y_train, epochs=5)
model.evaluate(x_test, y_test)
# Out:
# Train on 60000 samples
# Epoch 1/5
# WARNING:tensorflow:Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7feb06b49e18> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING: Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7feb06b49e18> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# 60000/60000 [==============================] - 8s 142us/sample - loss: 0.2194 - accuracy: 0.9352
# Epoch 2/5
# ...

# %%
print(model.history)

# %%
history=model.history.history

# %%
print(history)
# Out:
# {'loss': [0.21942676570415498, 0.09740569905626277, 0.0681567999864618, 0.053387180458412814, 0.04294643213110976], 'accuracy': [0.93516666, 0.9701667, 0.9788167, 0.9831, 0.98581666]}
